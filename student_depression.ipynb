# %% [markdown]
# # Student Depression Analysis

# %%
import analyze
import importlib
import pandas as pd
importlib.reload(analyze)


df = pd.read_csv('data\Student Depression Dataset.csv')


student_records = analyze.dataframe_to_dataclasses(df)
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\Jessi\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py:3442 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[28], line 4
#     importlib.reload(analyze)
#
#   File c:\Users\Jessi\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py:169 in reload
#     _bootstrap._exec(spec, module)
#
#   File <frozen importlib._bootstrap>:621 in _exec
#
#   File <frozen importlib._bootstrap_external>:936 in exec_module
#
#   File <frozen importlib._bootstrap_external>:1074 in get_code
#
#   File <frozen importlib._bootstrap_external>:1004 in source_to_code
#
#   File <frozen importlib._bootstrap>:241 in _call_with_frames_removed
#
#   File c:\Users\Jessi\OneDrive\Desktop\Jessica Miller - Data Science\Kaggle Student Depression Analysis\analyze.py:163
#     plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=['#66b3ff','#ff9999', #ff9997], startangle=140)
# ...

# %%
analyze.analyze_gender_based_depression(df)

# %%
analyze.analyze_health_habit_based_depresssion(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 analyze.analyze_health_habit_based_depresssion(df)
#
# AttributeError: module 'analyze' has no attribute 'analyze_health_habit_based_depresssion'

# %% [markdown]
# ### Analyze Correlation Between Sleep and Depression

# %% [markdown]
# Observations:
#
#     Meaningful Trend: Students sleeping less than 5 hours have the highest depression rate (~65%), confirming that short sleep is a risk factor.
#     Depression Rate Drops at 5–6 Hours: A moderate drop (~57%) at 5-6 hours, but the rate rises slightly again at 7-8 hours (~60%).
#     Lowest Depression at >8 Hours: Students with over 8 hours of sleep have the lowest depression rate (~52%), though still significant.

# %%
analyze.analyze_sleep_depression(df)

# %%
analyze.analyze_city_depression_instances(df)

# %%
analyze.analyze_degree_depression_instances(df)
