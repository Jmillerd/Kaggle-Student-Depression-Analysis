# %% [markdown]
# # Student Depression Analysis

# %%
import analyze
import importlib
import pandas as pd
importlib.reload(analyze)


df = pd.read_csv('data\Student Depression Dataset.csv')


student_records = analyze.dataframe_to_dataclasses(df)

# %% [markdown]
# ### Analyze Correlation No Depression and Depression Rates between Male and Female Students

# %% [markdown]
# 58.5 % of females identified as depressed.
# More males identified as depressed than female students, with 58.6%. Overall, the rates in males and females are largely similar in rates of depression.

# %%
analyze.analyze_gender_based_depression(df)

# %% [markdown]
# Dietary habits appear to have a correlation with depression identification, with 70.7% of students who claimed to have unhealthy dietary habits identifying at 70.7%, while those that claimed to have healthy dietary habits identifying as depressed at 45.5%.

# %% [markdown]
# ### Analyze Correlation Between Sleep and Depression

# %% [markdown]
# ### Analyze The Correlation Between Dietary Habits and Depression

# %%
analyze.analyze_health_habit_based_depresssion(df)

# %% [markdown]
# ### Analyze Correlation Between Sleep and Depression

# %% [markdown]
# Students sleeping less than 5 hours have the highest depression rate (~65%), confirming that short sleep is a risk factor. Depression Rate Drops at 5–6 Hours: A moderate drop (~57%) at 5-6 hours, but the rate rises slightly again at 7-8 hours (~60%). Lowest Depression at >8 Hours: Students with over 8 hours of sleep have the lowest depression rate (~52%), though still significant.

# %%
analyze.analyze_sleep_depression(df)
# Out:
# Correlation between Sleep Duration and Depression: -0.09

# %% [markdown]
# Kalyan, Hyderabad, and Srinagar have the highest rate of depression from respondents. This could be due to financial or academic pressures. A further analysis on the features may give more insight.

# %%
analyze.analyze_city_depression_instances(df)

# %% [markdown]
# Class 12 had the highest respondents that identified as depressed. This may be due to pressure before going to college, age, etc... factors. Will continue analysis on other features.

# %%
analyze.analyze_degree_depression_instances(df)
